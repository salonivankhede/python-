# %%
a = int(input("enter first number:"))
b = int(input("enter second number2:"))
c = int(input("enter third number3:"))
if a + b == c or b + c == a or c + a == b:
     print("Special Triplet")
else:
    print("Not Special")
# Out:
# enter first number: 3
# enter second number2: 2
# enter third number3: 6
# Not Special

# %%
a = int(input("enter number:"))
if a %4 == 0 and a %8!= 0:
    print("divisible by 4 only")
elif a%8==0:
    print("dividible by 8")
else:
    print("not divisible")
# Out:
# enter number: 12
# divisible by 4 only

# %%
basic = int(input("enter your salary:"))  #HRA = house rent allowence, DA= dearness allowanc
if basic>= 40000:
    HRA = basic*0.20
    DA = basic*0.15
elif basic>= 20000:
    HRA = basic*0.15
    DA = basic*0.1
else :
    HRA = basic*0.1
    DA = basic*0.05
finalsalary = basic + HRA + DA
print("basic salary",basic)
print("HRA",HRA)
print("DA",DA)
print("final salary",finalsalary)
# Out:
# enter your salary: 25000
# basic salary 25000
# HRA 3750.0
# DA 2500.0
# final salary 31250.0

# %%
a = int(input("enter date"))
b = int(input("enter month"))
c = int(input("enter year"))
r = a,b,c
if c%4 == 0:
    print("leap year",r)
else:
    print("not leap year",r)

print(r)
# Out:
# enter date 23
# enter month 7
# enter year 2003
# not leap year (23, 7, 2003)
# (23, 7, 2003)

# %%
password =(input("enter your password:"))
lenght = len(password)
if lenght>=8:
    print("strong")
elif 5<=lenght<=7:
    print("medium")
else:
    print("weak")
print(lenght)
# Out:
# enter your password: saloni23
# strong
# 8

# %%
a = int(input("num1:"))
b = int(input("num2:"))
c = int(input("num3:"))
if a<b<c:
    print("increasing")
elif a>b>c:
    print("decreasing")
else:
    print("neither")
# Out:
# num1: 22
# num2: 24
# num3: 37
# increasing

# %%
bill= int(input("enter amount:"))
if bill>=5000:
    discount= bill*0.20
elif bill>=3000:
    discount=bill*0.1
else:
     discount=0
final_amount = bill-discount
print("final amount to pay",final_amount)
# Out:
# enter amount: 4500
# final amount to pay 4050.0

# %%
a = int(input("enter number:"))
if a%2==0 and a%4==0:
    print(a,"super even")
elif a%2==0 and a%4!=0:
    print(a,"normal even")
else:
    print("odd")
# Out:
# enter number: 10
# 10 normal even

# %%
a =input("signal colour:")
if a=="red":
     print("stop")
elif a=="yellow":
    time = int(input("enter time in second:"))
    if time < 5:
         print("ready")
    else:
        print("wait")
elif a=="green":
     print("go")
else:
    print("invalid signal")
# Out:
# signal colour: yellow
# enter time in second: 3
# ready

# %%
temperature = int(input("enter temperature:"))
if temperature <10:
    print("too cold")
elif temperature <= 25:
    print("pleasant")
else:
    humidity = int(input("enter humidity:"))
    if humidity > 70:
        print("hot & humid")
    else:
        print("hot")
# Out:
# enter temperature: 90
# enter humidity: 98
# hot & humid
