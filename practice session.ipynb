# %%
a = 10 #1
b = 5
c = 2
r= a+b*c
print(r)
# Out:
# 20

# %%
a = 10 #2
b = 5
c = 2
r = (a+b)*c
print(r)
# Out:
# 30

# %%
a = 20 #3
b = 4 
c = 2
r = a-b**c
print(r)
# Out:
# 4

# %%
a= 100 #4
b= 5
c= 2
r= a//b*c
print(r)
# Out:
# 40

# %%
a= 2 #5
b= 3
c= 2
r = a**b**c
print(r)
# Out:
# 512

# %%
a = 4 #5
b= 2
c = 3
r=a*b**c
print(r)
# Out:
# 32

# %%
a= 16 #6
b=2
c=2
r = a//b**c
print(r)
# Out:
# 4

# %%
a = 9 #7
b =6
c = 2
d = 2
r=a+b*c**d
print(r)
# Out:
# 33

# %%
a=10 #8
b=5
c=2
r=a>b
print(r)
d=b>c
print(d)
# Out:
# True
# True

# %%
a=10 #9
b=5
c=2
r=a>b
print(r)
d=b<c
print(d)
# Out:
# True
# False

# %%
a=10 #10
b=5
r=a>b
print("not",r)
# Out:
# not True

# %%
a=b #11
b=c
c=d
r=a==b,b==c,c==d
print(r)
# Out:
# (False, True, True)

# %%
a=5 #12
b=10
c=20
r=a<b<c
print(r)
# Out:
# True

# %%
x=5 #13
x += 3*2
r=x+x
print(x)
# Out:
# 11

# %%
x = 10 #14
x*=2+3
r=(x+x)
print(r)
# Out:
# 100

# %%
x=5 #15
x=x==5
r=(x+x)
print(r)
# Out:
# 2

# %%
x=2 #16
x+=x==1
r=(x+x)
print(r)
# Out:
# 4

# %%
x=1 #17
x+=x==1
r=x=x
print(r)
# Out:
# 2

# %%
a= "hello" #1
r=input("enetr a word)
print(a,"is present in a")
# Out:
# enetr a word l
# hello is present in a

# %%
a = (2,3,5,7,11) #2
num = int(input("enetr number:"))
if num%2 in a:
    print("even number")
else:
    print("odd number")
# Out:
# enetr number: 2
# odd number

# %%
a = ("alico","bob","john123") #3
name = input("enter name")
if name in a:
    print("username already taken")
else:
    print("not")
# Out:
# enter name alico
# username already taken

# %%
a= "the sun rises in the east"#4
r= input("a word")
if r in a:
    print(" is present in the sentance")
else: 
    print("not")
# Out:
# a word the
#  is present in the sentance

# %%
cart=("brad","eggs") #5
a = input("enter item")
if a in cart:
    print(" item in the cart")
else:
    print("not in the cart")
# Out:
# enter item milk
# not in the cart

# %%
a = (1,2) #1
b = a
num = int(input("enter number"))
if b in a:
    print("a and b rafer to the same object",a)
else:
    print("not in the list")
# Out:
# enter number 2
# not in the list

# %%
list1 = (1,2,3) #2
list2 = (1,2,3)
number = int(input("enter digit"))
if list2 in list1:
    print("list1 and list2  refer to the same object")
else:
    print("list1 and list2  do not refer to the same object")
# Out:
# enter digit 3
# list1 and list2  do not refer to the same object

# %%
r=("a,b,s,d,e") #3
k=("e,f,g,h,i")
user = input(" enter word")
if k in r :
    print(" the variable in the r")
else:
    print(" the variable is none")
# Out:
#  enter word g
#  the variable is none
