# %%
d1 = {"even":(20,30,40),
      "odd":[1,3,6],
      "null":{"ram":23,"shyam":45,"naam":24}}
print(d1)
print(len(d1))
# Out:
# {'even': (20, 30, 40), 'odd': [1, 3, 6], 'null': {'ram': 23, 'shyam': 45, 'naam': 24}}
# 3

# %%
d = {
    "brand":"ford",
    "model":"mustang",
    "year":1964
}
d["model"]
# Out:
# 'mustang'

# %%
d.get("model")
# Out:
# 'mustang'

# %%
d.values()
# Out:
# dict_values(['ford', 'mustang', 1964])

# %%
d.items()
# Out:
# dict_items([('brand', 'ford'), ('model', 'mustang'), ('year', 1964)])

# %%
d.keys()
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
print(max(d))
# Out:
# year

# %%
print(min(d))
# Out:
# brand

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
dict(d)
# Out:
# {'brand': 'ford', 'model': 'mustang', 'year': 1964}

# %%
thisdict = dict(name =  "jhon",age = 67,country = "norway")
print(thisdict)
# Out:
# {'name': 'jhon', 'age': 67, 'country': 'norway'}

# %%
d1 = {30:"ram",40:"shyam",60:"reem"}
print(sum(d1))
# Out:
# 130

# %%
for i in d1:
    print(i,d1[i])
# Out:
# 30 ram
# 40 shyam
# 60 reem

# %%
d = {}
d["hello"]=30
print(d)
# Out:
# {'hello': 30}

# %%
d["hyy"]=40
d
# Out:
# {'hello': 30, 'hyy': 40}

# %%
di = {}
di["ab"]=1
di["bn"]=2
di["cn"]=8
di["df"]=0
di["lm"]=5
di
# Out:
# {'ab': 1, 'bn': 2, 'cn': 8, 'df': 0, 'lm': 5}

# %%
di.values()
# Out:
# dict_values([1, 2, 8, 0, 5])

# %%
di
# Out:
# {'ab': 1, 'bn': 2, 'cn': 8, 'df': 0, 'lm': 5}

# %%
di.update({"ab":90})
di
# Out:
# {'ab': 90, 'bn': 2, 'cn': 8, 'df': 0, 'lm': 5}

# %%
 di.copy()
# Out:
# {'ab': 90, 'bn': 2, 'cn': 8, 'df': 0, 'lm': 5}

# %%
di.clear()
print(di)
# Out:
# {}

# %%
d1 = {"a":3,"c":0,"b":9}
d1.pop("a")
# Out:
# 3

# %%
d1.popitem()
# Out:
# ('b', 9)

# %%
d3 = {}
d3.fromkeys([1,2],500)
# Out:
# {1: 500, 2: 500}

# %%
keys = ["a","b","c"]
values = [1,2,3]
d = dict.fromkeys(keys)
print(d)
d["a"]=1
d["b"]=2
d["c"]=3
print(d)
# Out:
# {'a': None, 'b': None, 'c': None}
# {'a': 1, 'b': 2, 'c': 3}

# %%
d3={}
d3["hello"]=30
print(d3)
a = d3.fromkeys("f",90)
d3.update(a)
print(a)
print(d3)
# Out:
# {'hello': 30}
# {'f': 90}
# {'hello': 30, 'f': 90}
