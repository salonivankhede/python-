# %%
class Vehicle:
    def __init__(self,brand,speed):
        self.brand = brand
        self.speed = speed 
class Car(Vehicle):
    def __init__(self,brand,speed,fuel_type):
        super().__init__(brand,speed)
        self.fuel_type = fuel_type
c = Car("Toyoto",120,"Petrol")
print(c.brand,c.speed,c.fuel_type)
# Out:
# Toyoto 120 Petrol

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
class Student(Person):
    def __init__(self,name,age,grade):
        super().__init__(name,age)
        self.grade = grade
s = Student("abhay",24,"A+")
print(s.name,s.age,s.grade)
# Out:
# abhay 24 A+

# %%
import math
class Shape:
    def area(self):
        pass
class Rectangle(Shape):
    def __init__(self,lenght,width):
        self.lenght = lenght
        self.width = width
    def area(self):
        return self.lenght*self.width
class Circle(Shape):
    def __init__(self,radius):
        self.radius = radius
    def area(self):
        math.pi * self.radius **2
r = Rectangle(5,6)
c = Circle(3)
print("Rectangle area :",r.area())
print("Circle area :",c.area())
# Out:
# Rectangle area : 30
# Circle area : None

# %%
class Device:
    def __init__(self,brand,price):
        self.brand = brand
        self.price = price
class Laptop(Device):
    pass
class Mobile(Device):
    pass 
a = Laptop("hp",50000)
b = Mobile("google",75000)
print(a.brand,a.price,  b.brand,b.price)
# Out:
# hp 50000 google 75000

# %%
class BankAccount:
    def __init__(self,account_number,balance):
        self.account_number = account_number
        self.balance = balance
class SavingAccount(BankAccount):
    def __init__(self,account_number,balance,interest_rate):
        super().__init__(account_number,balance)
        self.interest_rate = interest_rate

s = SavingAccount(4526,25000,5)
print(s.account_number,s.balance,s.interest_rate)
# Out:
# 4526 25000 5

# %%
class Animal:
    def eat(self):
        print("not all animals are pets")
class Mammal(Animal):
    def walk(self):
        print("mammal walks")
class Dog(Mammal):
    def bark(self):
        print("dog barks")
d =  Dog()
d.eat()
d.walk()
d.bark()
# Out:
# not all animals are pets
# mammal walks
# dog barks

# %%
class Employee:
    def work(self):
        print("employee works")
class Manager(Employee):
    def manage(self):
        print("Manager manages team")
class SeniorManager(Manager):
    def strategy(self):
        print("Senior manager makes strategy")
s = SeniorManager()
s.work()
s.manage()
s.strategy()
# Out:
# employee works
# Manager manages team
# Senior manager makes strategy

# %%
class Vehicle:
    def __init__(self,brand):
        self.brand = brand
class Car(Vehicle):
    def __init__(self,brand,speed):
        super().__init__(brand)
        self.speed = speed
class ElectricCar(Car):
    def __init__(self,brand,speed,battery_capacity):
        super().__init__(brand,speed)
        self.battery_capacity = battery_capacity
e = ElectricCar("Tesla",200,"75kwh")
print(e.brand,e.speed,e.battery_capacity)
# Out:
# Tesla 200 75kwh

# %%
class Person:
    def __init__(self,name):
        self.name = name
class Employee(Person):
    def __init__(self,name,emp_id):
        super().__init__(name)
        self.emp_id = emp_id
class Developer(Employee):
    def __init__(self,name,emp_id,language):
        super().__init__(name,emp_id)
        self.language = language
a = Developer("Lucky", 123, "Python")
print(a.name,a.emp_id,a.language)
# Out:
# Lucky 123 Python

# %%
class University:
    def __init__(self,uname):
        self.uname = uname
class Department(University):
    def __init__(self,uname,dname):
        super().__init__(uname)
        self.dname = dname
class Course(Department):
    def __init__(self,uname,dname,cname):
        super().__init__(uname,dname)
        self.cname = cname
c = Course("DAVV","Economics","BA")
print(c.uname,c.dname,c.cname)
# Out:
# DAVV Economics BA
